# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict
from sklearn import metrics

from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)

# %%
df['diagnosis'] = df['diagnosis'].map({'B':0, 'M' : 1})

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
sns.countplot(df['diagnosis'])
# Out:
# C:\Users\woong\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
train, test=train_test_split(df, test_size=0.2, random_state=2020)

xtrain = train.drop(['diagnosis'], axis=1)
ytrain = train.diagnosis

xtest = test.drop(['diagnosis'], axis=1)
ytest = test.diagnosis

# %%
model = svm.SVC(gamma='scale')

model.fit(xtrain,ytrain)

y_pred = model.predict(xtest)

print('SVM: %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# SVM: 91.23

# %%
model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)

y_pred = model.predict(xtest)

print("DecisionTreeClassifier: %.2f" % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# DecisionTreeClassifier: 93.86

# %%
model = KNeighborsClassifier()
model.fit(xtrain, ytrain)

y_pred = model.predict(xtest)

print("KNeighborsClassifier: %.2f" % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# KNeighborsClassifier: 92.98

# %%
model = LogisticRegression(solver='lbfgs', max_iter=2000)
model.fit(xtrain, ytrain)

y_pred = model.predict(xtest)

print("LogisticRegression: %.2f" % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# LogisticRegression: 97.37
# C:\Users\woong\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(xtrain, ytrain)

y_pred = model.predict(xtest)

print("RandomForestClassifier: %.2f" % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# RandomForestClassifier: 97.37

# %%
features = pd.Series(
    model.feature_importances_,
    index=xtrain.columns
).sort_values(ascending=False)

print(features)
# Out:
# area_worst                 0.133528
# concave points_mean        0.121088
# radius_worst               0.117933
# concave points_worst       0.107698
# perimeter_worst            0.084328
# perimeter_mean             0.067771
# radius_mean                0.041940
# area_mean                  0.038088
# concavity_worst            0.037093
# concavity_mean             0.036781
# area_se                    0.035493
# radius_se                  0.021972
# compactness_mean           0.020511
# perimeter_se               0.019077
# texture_worst              0.016667
# texture_mean               0.015405
# smoothness_worst           0.012907
# compactness_worst          0.011241
# symmetry_worst             0.008337
# fractal_dimension_worst    0.007403
# smoothness_mean            0.006871
# concavity_se               0.005986
# symmetry_se                0.004844
# smoothness_se              0.004778
# fractal_dimension_se       0.004701
# texture_se                 0.004434
# ...

# %%
t5 = features.keys()[:5]

print(t5)
# Out:
# Index(['area_worst', 'concave points_mean', 'radius_worst',
#        'concave points_worst', 'perimeter_worst'],
#       dtype='object')

# %%
model = svm.SVC(gamma='scale')

model.fit(xtrain[t5],ytrain)

y_pred = model.predict(xtest[t5])

print('SVM(t5): %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# SVM(t5): 90.35

# %%
model = DecisionTreeClassifier()

model.fit(xtrain[t5],ytrain)

y_pred = model.predict(xtest[t5])

print('DecisionTreeClassifier(t5): %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# DecisionTreeClassifier(t5): 91.23

# %%
model = KNeighborsClassifier()

model.fit(xtrain[t5],ytrain)

y_pred = model.predict(xtest[t5])

print('KNeighborsClassifier(tf): %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# KNeighborsClassifier(tf): 89.47

# %%
model = LogisticRegression(solver='lbfgs', max_iter=2000)

model.fit(xtrain[t5],ytrain)

y_pred = model.predict(xtest[t5])

print('LogisticRegression(tf): %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# LogisticRegression(tf): 89.47

# %%
model = RandomForestClassifier(n_estimators=100)

model.fit(xtrain[t5],ytrain)

y_pred = model.predict(xtest[t5])

print('RandomForestClassifier(t5): %.2f' % (metrics.accuracy_score(y_pred, ytest) * 100))
# Out:
# RandomForestClassifier(t5): 92.98

# %%
model = svm.SVC(gamma='scale')

cv = StratifiedKFold(n_split=5, random_state=2020)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17208/3939601690.py in <module>
#       1 model = svm.SVC(gamma='scale')
#       2
# ----> 3 cv = StratifiedKFold(n_split=5, random_state=2020)
#
# TypeError: __init__() got an unexpected keyword argument 'n_split'
